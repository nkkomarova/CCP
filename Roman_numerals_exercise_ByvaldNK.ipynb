# %% [markdown]
# # Roman numerals

# %% [markdown]
# ## I. Roman numerals to decimals
#
# Write a function which receives a Roman numeral written out as a string, and returns an integer representing the decimal form of the input number.

# %%
mapping = {"I" : 1, 
           "V" : 5,
           "X" : 10,
           "L" : 50,
           "C" : 100,
           "D" : 500,
           "M" : 1000}

# %%
def roman_to_decimal(rom):
    
    l=len(rom)
    summ=0
    for i in range(l-1):
        if mapping[rom[i]] < mapping[rom[i+1]]:
            summ = summ - mapping[rom[i]]
        elif mapping[rom[i]] >= mapping[rom[i+1]]:
            summ = summ + mapping[rom[i]]
    summ = summ + mapping[rom[-1]]
    dec = summ
    return dec

# %% [markdown]
# Here are some tests for you to test your code. Your code must pass all of them. You also need to come up with several more tests (your choice).

# %%
test_pairs = [("IX", 9), ("XI", 11), ("MCCII", 1202), ("MMXVIII", 2018), ("XLIX", 49)]

for rom, dec in test_pairs:
    converted = roman_to_decimal(rom)
    print(converted == dec)
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# Now you can run tests in file `tests_roman_to_decimal.txt`. You need to insert a number of false results and listed false results in respective fields in Google Form for this lesson.

# %%
p_roman = "C:\\Users\\Nataliya\\Desktop\\ВШЭ\\Программирование сложных вычислений\\Lesson 1\\Roman numerals\\tests_roman_to_decimal.txt"
with open(p_roman, "rb") as fp_roman:
    lines_roman=fp_roman.readlines()

test_data_roman = [line.strip().decode("ascii").split(',') for line in lines_roman]
test_data_roman = [(line[0], int(line[1])) for line in test_data_roman]

# %% [markdown]
# ## II. Decimal numbers to roman numerals.
#
# The maximum grade for first task (Roman to decimal) is 7 on the 10-point HSE scale. For extra credit, complete the second task: *given a decimal number, convert it to the Roman form*.

# %%
def decimal_to_roman(dec):
    """Convert a decimal to the Roman form.
    
    Parameters
    ----------
    dec : int
        A positive integer number
    
    Returns
    -------
    rom : str
        A string representation of a Roman numeral form of `dec`.
    """
    rom = ''
    for arabic, roman in zip((1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1),
                             'M     CM   D    CD   C    XC  L   XL  X   IX V  IV I'.split()):
        rom += dec // arabic * roman
        dec %= arabic
    return rom

# %% [markdown]
# You need to come up with test cases to show that your conversion works as expected.
# NB: the conversion is ambiguous in some cases. Any valid conversion is accepted.

# %% [markdown]
# Now you can run tests in file `tests_decimal_to_roman.txt`. You need to insert a number of false results and listed false results in respective fields in Google Form for this lesson.

# %%
p_decimal = "C:\\Users\\Nataliya\\Desktop\\ВШЭ\\Программирование сложных вычислений\\Lesson 1\\Roman numerals\\tests_decimal_to_roman.txt"
with open(p_decimal, "rb") as fp_decimal:
    lines_decimal=fp_decimal.readlines()

test_data_decimal = [line.strip().decode("ascii").split(',') for line in lines_decimal]
test_data_decimal = [(line[0], int(line[1])) for line in test_data_decimal]

for rom, dec in test_data_decimal:
    converted = decimal_to_roman(dec)
    print(converted == rom)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
